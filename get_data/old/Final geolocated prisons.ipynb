# %%
import pandas as pd 
pd.options.display.max_columns = 1000
pd.options.display.max_colwidth = 1000

# %%
all_prisons = pd.read_csv("old_csv_data/all_prison_data_final_manual.csv")

# %%
all_prisons["lat"]= all_prisons["lat"].fillna(all_prisons["lat_manual"])
all_prisons["lng"]= all_prisons["lng"].fillna(all_prisons["lng_manual"])

# %%
groups = pd.read_csv("old_csv_data/prison_groups_lookup.csv")

# %%
# Out:
#             prison_name_original    prison_name_group
# 0                     Acklington           Acklington
# 1        Acklington / Castington       Northumberland
# 2                      Altcourse            Altcourse
# 3                       Ashfield             Ashfield
# 4                        Ashwell              Ashwell
# 5                  Askham Grange        Askham Grange
# 6                      Aylesbury            Aylesbury
# 7                        Bedford              Bedford
# 8                       Belmarsh             Belmarsh
# 9                     Birmingham           Birmingham
# 10                Blantyre House       Blantyre House
# 11                    Blundeston           Blundeston
# 12                     Brinsford            Brinsford
# 13                       Bristol              Bristol
# 14                       Brixton              Brixton
# 15                   Bronzefield          Bronzefield
# ...
